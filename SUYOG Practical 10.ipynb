# %%
print("Suyog Ghadi")
print("24204C0024")
# Out:
# Suyog Ghadi
# 24204C0024

# %%
import math

Vm = float(input("Enter the peak value of output voltage (Vm): "))

Vdc = Vm / math.pi

print("DC output voltage (Vdc) =", Vdc)
# Out:
# Enter the peak value of output voltage (Vm):  84
# DC output voltage (Vdc) = 26.73803043943842

# %%
import statistics
data = [38, 55, 100, 89, 25, 56, 99]
mean_value = statistics.mean(data)
median_value = statistics.median(data)
mode_value = statistics.mode(data)
std_dev = statistics.stdev(data)

print("Data: ", data)
print("Mean (Average) =", mean_value)
print("Median (Middle Value) =", median_value)
print("Mode (Most Frequent Value) =", mode_value)
print("Standard Deviation =", std_dev)
# Out:
# Data:  [38, 55, 100, 89, 25, 56, 99]
# Mean (Average) = 66
# Median (Middle Value) = 56
# Mode (Most Frequent Value) = 38
# Standard Deviation = 30.166206257996713

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Error: Division by zero!"

print("Welcome to User-Defined Calculator!")

num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))

print("Addition:", add(num1, num2))
print("Subtraction:", subtract(num1, num2))
print("Multiplication:", multiply(num1, num2))
print("Division:", divide(num1, num2))
# Out:
# Welcome to User-Defined Calculator!
# Enter first number:  2150
# Enter second number:  54
# Addition: 2204.0
# Subtraction: 2096.0
# Multiplication: 116100.0
# Division: 39.81481481481482

# %%
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
 # Simulated calc module
def add(a, b):
    return a + b
# Main program
print(add(5, 3))
# Out:
# 8
