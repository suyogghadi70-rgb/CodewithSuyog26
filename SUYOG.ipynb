# %%
print("suyog")
# Out:
# suyog

# %%
print("rollno. 24204C0024")
# Out:
# rollno. 24204C0024

# %%
print("Dept:=TE")
# Out:
# Dept:=TE

# %% [markdown]
# Write a program to check whether entered frequency is radio frequency or audio frequency.

# %%
frequency = float(input("Enter frequency in Hz: "))

if frequency < 20000:
    print("The entered frequency is Audio Frequency (AF)")
else:
    print("The entered frequency is Radio Frequency (RF)")
# Out:
# Enter frequency in Hz:  14444
# The entered frequency is Audio Frequency (AF)

# %% [markdown]
# Program to display RF bands using if–elif

# %%
f=float(input("Enter Frequency in Hz:"))
if 30000 <= f <= 300000:
    print("VLF Band")
elif 300000 <= f <= 3000000:
    print("LF Band")
elif 3000000 <= f <= 30000000:
    print("VHF Band")
else:
    print ("Frequency not in standard RF range")
# Out:
# Enter Frequency in Hz: 244
# Frequency not in standard RF range

# %% [markdown]
# Program for resistor color code using selection logic

# %%
color = input("Enter resistor color: ").lower()

if color == "black":
    print("0")
elif color == "brown":
    print("1")
elif color == "red":
    print("2")
elif color == "orange":
    print("3")
elif color == "yellow":
    print("4")
elif color == "green":
    print("5")
elif color == "blue":
    print("6")
elif color == "violet":
    print("7")
elif color == "grey":
    print("8")
elif color == "white":
    print("9")
else:
    print("Invalid color")
# Out:
# Enter resistor color:  violet
# 7

# %% [markdown]
# Write a Python program that checks if the voltage of a battery is greater than 3.7V and prints "Battery is charged" if true.

# %%
voltage = float(input("Enter battery voltage: "))

if voltage > 3.7:
    print("Battery is charged")
else:
    print("Battery is not charged")
# Out:
# Enter battery voltage:  3.2
# Battery is not charged

# %% [markdown]
# Write a Python program that checks if a resistor value is within a tolerance range (e.g., 5% tolerance for a 100Ω resistor) and prints whether it is within tolerance or not.

# %%
resistance = float(input("Enter resistor value in ohms: "))

if 95 <= resistance <= 105:
    print("Resistor is within tolerance")
else:
    print("Resistor is out of tolerance")
# Out:
# Enter resistor value in ohms:  100
# Resistor is within tolerance

# %%
f = float(input("Frequency: "))
if f < 20000:
    print("AF")
else:
    print("RF")
# Out:
# Frequency:  20500
# RF

# %%
clr = input("Color: ")
if clr == "red":
    print(2)
# Out:
# Color:  red
# 2

# %% [markdown]
# Q1: Check if a number is positive

# %%
number = int(input("Enter a number: "))
if number > 0:
    print("Positive")
# Out:
# Enter a number:  5
# Positive

# %% [markdown]
# Q2: Check if age is eligible to vote

# %%
age = int(input("Enter age: "))
if age >= 18:
    print("Eligible to vote")
# Out:
# Enter age:  20
# Eligible to vote

# %% [markdown]
# Q3: Check if temperature is high

# %%
temperature = int(input("Enter temperature: "))
if temperature > 40:
    print("High Temperature")
# Out:
# Enter temperature:  45
# High Temperature

# %% [markdown]
# Q4: Check if number is even

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("Even Number")
# Out:
# Enter a number:  4
# Even Number

# %% [markdown]
# Q5: Check if password is correct

# %%
password = input("Enter password: ")
if password == "admin":
    print("Access Granted")
# Out:
# Enter password:  admin
# Access Granted

# %% [raw]
# 2: IF–ELSE

# %% [markdown]
# Q1: Check if a number is positive or negative

# %%
number = int(input("Enter a number: "))
if number >= 0:
    print("Positive")
else:
    print("Negative")
# Out:
# Enter a number:  11
# Positive

# %% [markdown]
# Q2: Check pass or fail

# %%
IF marks >= 40 THEN
    PRINT "Pass"
ELSE
    PRINT "Fail"
ENDIF

# %%
marks = int(input("Enter marks: "))

if marks >= 40:
    print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  41
# Pass

# %% [markdown]
# Q3: Check even or odd

# %%
IF number MOD 2 = 0 THEN
    PRINT "Even"
ELSE
    PRINT "Odd"
ENDIF

# %%
number = int(input("Enter number: "))
if number % 2 == 0:
    print("Even")
else:
    print("Odd")
# Out:
# Enter number:  3
# Odd

# %% [markdown]
# Q4: Check eligible for driving

# %%
IF age >= 18 THEN
    PRINT "Eligible"
ELSE
    PRINT "Not Eligible"
ENDIF

# %%
age = int(input("Enter age: "))
if age >= 18:
    print("Eligible")
else:
    print("Not Eligible")
# Out:
# Enter age:  17
# Not Eligible

# %% [markdown]
# Q5: Check login status

# %%
IF login = TRUE THEN
    PRINT "Welcome"
ELSE
    PRINT "Invalid Login"
ENDIF

# %%
login = input("Enter login status (true/false): ").lower()

if login == "true":
    print("Welcome")
else:
    print("Invalid Login")
# Out:
# Enter login status (true/false):  true
# Welcome

# %% [raw]
# IF–ELIF–ELSE

# %% [markdown]
# Q1: Grade based on marks

# %%
IF marks >= 75 THEN
    PRINT "A"
ELIF marks >= 60 THEN
    PRINT "B"
ELSE
    PRINT "C"
ENDIF

# %%
marks = int(input("Enter marks: "))
if marks >= 75:
    print("A")
elif marks >= 60:
    print("B")
else:
    print("C")
# Out:
# Enter marks:  71
# B

# %% [markdown]
# Q2: Number sign

# %%
IF number > 0 THEN
    PRINT "Positive"
ELIF number = 0 THEN
    PRINT "Zero"
ELSE
    PRINT "Negative"
ENDIF

# %%
number = int(input("Enter a number: "))
if number > 0:
    print("Positive")
elif number == 0:
    print("Zero")
else:
    print("Negative")
# Out:
# Enter a number:  5
# Positive

# %% [markdown]
# Q3: Temperature level

# %%
IF temp > 40 THEN
    PRINT "High"
ELIF temp > 20 THEN
    PRINT "Normal"
ELSE
    PRINT "Low"
ENDIF

# %%
temp = float(input("Enter temperature: "))
if temp > 40:
    print("High")
elif temp > 20:
    print("Normal")
else:
    print("Low")
# Out:
# Enter temperature:  45
# High

# %% [markdown]
# Q4: Day type

# %%
IF day = "Sunday" THEN
    PRINT "Holiday"
ELIF day = "Saturday" THEN
    PRINT "Half Day"
ELSE
    PRINT "Working Day"
ENDIF

# %%
day = input("Enter day: ")
if day == "Sunday":
    print("Holiday")
elif day == "Saturday":
    print("Half Day")
else:
    print("Working Day")
# Out:
# Enter day:  Friday
# Working Day

# %% [markdown]
# Q5: Speed check

# %%
IF speed > 80 THEN
    PRINT "Overspeed"
ELIF speed > 40 THEN
    PRINT "Normal"
ELSE
    PRINT "Slow"
ENDIF

# %%
speed = int(input("Enter speed: "))
if speed > 80:
    print("Overspeed")
elif speed > 40:
    print("Normal")
else:
    print("Slow")
# Out:
# Enter speed:  100
# Overspeed

# %% [raw]
# NESTED IF–ELSE

# %% [markdown]
# Q1: Largest of two numbers

# %%
IF a > b THEN
    PRINT "A is largest"
ELSE
    IF b > a THEN
        PRINT "B is largest"
    ELSE
        PRINT "Both equal"
    ENDIF
ENDIF

# %%
a = int(input("Enter value of a: "))
b = int(input("Enter value of b: "))
if a > b:
    print("A is largest")
else:
    if b > a:
        print("B is largest")
    else:
        print("Both equal")
# Out:
# Enter value of a:  24
# Enter value of b:  44
# B is largest

# %% [markdown]
# Q2: Result with distinction

# %%
IF marks >= 40 THEN
    IF marks >= 75 THEN
        PRINT "Distinction"
    ELSE
        PRINT "Pass"
    ENDIF
ELSE
    PRINT "Fail"
ENDIF

# %%
marks = int(input("Enter marks: "))
if marks >= 40:
    if marks >= 75:
        print("Distinction")
    else:
        print("Pass")
else:
    print("Fail")
# Out:
# Enter marks:  71
# Pass

# %% [markdown]
# Q3: Login and role check

# %%
IF login = TRUE THEN
    IF role = "Admin" THEN
        PRINT "Admin Access"
    ELSE
        PRINT "User Access"
    ENDIF
ELSE
    PRINT "Login Failed"
ENDIF

# %%
login = input("Login status (true/false): ").lower()
role = input("Enter role: ")

if login == "true":
    if role == "Suyog":
        print("Suyog Access")
    else:
        print("User Access")
else:
    print("Login Failed")
# Out:
# Login status (true/false):  true
# Enter role:  Suyog
# Suyog Access

# %% [markdown]
# Q4: Weather advice

# %%
IF raining = TRUE THEN
    IF umbrella = TRUE THEN
        PRINT "Go Outside"
    ELSE
        PRINT "Stay Inside"
    ENDIF
ELSE
    PRINT "Enjoy the Day"
ENDIF

# %%
raining = input("Is it raining? (true/false): ").lower()
umbrella = input("Do you have an umbrella? (true/false): ").lower()

if raining == "true":
    if umbrella == "true":
        print("Go Outside")
    else:
        print("Stay Inside")
else:
    print("Enjoy the Day")
# Out:
# Is it raining? (true/false):  true
# Do you have an umbrella? (true/false):  false
# Stay Inside

# %% [markdown]
# Q5: Exam eligibility

# %%
IF attendance >= 75 THEN
    IF fees_paid = TRUE THEN
        PRINT "Eligible for Exam"
    ELSE
        PRINT "Pay Fees"
    ENDIF
ELSE
    PRINT "Low Attendance"
ENDIF

# %%
attendance = int(input("Enter attendance percentage: "))
fees_paid = input("Fees paid? (true/false): ").lower()

if attendance >= 75:
    if fees_paid == "true":
        print("Eligible for Exam")
    else:
        print("Pay Fees")
else:
    print("Low Attendance")
# Out:
# Enter attendance percentage:  71
# Fees paid? (true/false):  false
# Low Attendance
