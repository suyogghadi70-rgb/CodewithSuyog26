# %%
print("Suyog Ghadi")
print("24204C0024")
# Out:
# Suyog Ghadi
# 24204C0024

# %% [markdown]
# Program for Linear Search

# %%
def linear_search(arr, key):
    for i in range(len(arr)):
        if arr[i] == key:
            return i   
    return -1          


arr = list(map(int, input("Enter elements separated by space: ").split()))
key = int(input("Enter element to search: "))

result = linear_search(arr, key)

if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")
# Out:
# Enter elements separated by space:  5 15 25 35
# Enter element to search:  10
# Element not found

# %% [markdown]
# Program for Binary Search

# %%
def binary_search(arr, key):
    low = 0
    high = len(arr) - 1

    while low <= high:
        mid = (low + high) // 2

        if arr[mid] == key:
            return mid
        elif arr[mid] < key:
            low = mid + 1
        else:
            high = mid - 1

    return -1



arr = list(map(int, input("Enter sorted elements separated by space: ").split()))
key = int(input("Enter element to search: "))

result = binary_search(arr, key)

if result != -1:
    print("Element found at index:", result)
else:
    print("Element not found")
# Out:
# Enter sorted elements separated by space:  1 3 5 7 9 11
# Enter element to search:  7
# Element found at index: 3

# %% [markdown]
# Program to search for a character in a string (Linear Search logic)

# %%
def search_character(text, key):
    for i in range(len(text)):
        if text[i] == key:
            return i   
    return -1          


# Taking input
text = input("Enter a string: ")
key = input("Enter character to search: ")

result = search_character(text, key)

if result != -1:
    print("Character found at index:", result)
else:
    print("Character not found")
# Out:
# Character found at index: 0
