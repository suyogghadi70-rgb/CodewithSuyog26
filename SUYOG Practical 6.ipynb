# %%
print("Suyog Ghadi")
print("24204C0024")
# Out:
# Suyog Ghadi
# 24204C0024

# %% [markdown]
# Programming Questions with Answer

# %% [markdown]
# Shopping Cart System – Set Based Programming Problem
# Design and implement a Shopping Cart System using a set data structure to manage product IDs added to a cart.

# %%
cart1 = set()

while True:
    print("\n====== SHOPPING CART SYSTEM (SET) ======")
    print("1. Add product IDs to cart")
    print("2. Display all products in cart")
    print("3. Total unique products count")
    print("4. Highest and Lowest product ID")
    print("5. Search product ID")
    print("6. Remove product ID from cart")
    print("7. Display premium products (>= given value)")
    print("8. Union & Intersection with another cart")
    print("9. Display cart in sorted order")
    print("10. Exit")

    choice = int(input("Enter your choice: "))

    if choice == 1:
        n = int(input("How many products to add? "))
        for i in range(n):
            pid = int(input(f"Enter product ID {i+1}: "))
            cart1.add(pid)   # duplicates automatically ignored
        print("Products added successfully!")

    elif choice == 2:
        if len(cart1) == 0:
            print("Cart is empty.")
        else:
            print("Cart Products:", cart1)

    elif choice == 3:
        print("Total Unique Products =", len(cart1))

    elif choice == 4:
        if len(cart1) == 0:
            print("Cart is empty.")
        else:
            print("Highest Product ID =", max(cart1))
            print("Lowest Product ID =", min(cart1))

    elif choice == 5:
        pid = int(input("Enter product ID to search: "))
        if pid in cart1:
            print("Product ID found in cart.")
        else:
            print("Product ID not found.")

    elif choice == 6:
        pid = int(input("Enter product ID to remove: "))
        if pid in cart1:
            cart1.remove(pid)
            print("Product removed successfully!")
        else:
            print("Product ID not found in cart.")

    elif choice == 7:
        if len(cart1) == 0:
            print("Cart is empty.")
        else:
            limit = int(input("Enter premium product ID limit: "))
            premium = {p for p in cart1 if p >= limit}
            print("Premium Products:", premium)

    elif choice == 8:
        cart2 = set()
        n = int(input("How many products in second user's cart? "))
        for i in range(n):
            pid = int(input(f"Enter product ID {i+1}: "))
            cart2.add(pid)

        print("Cart1:", cart1)
        print("Cart2:", cart2)
        print("Union (All unique products):", cart1.union(cart2))
        print("Intersection (Common products):", cart1.intersection(cart2))

    elif choice == 9:
        if len(cart1) == 0:
            print("Cart is empty.")
        else:
            print("Sorted Cart Products:", sorted(cart1))

    elif choice == 10:
        print("Exiting... Thank you!")
        break

    else:
        print("Invalid choice! Try again.")
# Out:
# ====== SHOPPING CART SYSTEM (SET) ======
# 1. Add product IDs to cart
# 2. Display all products in cart
# 3. Total unique products count
# 4. Highest and Lowest product ID
# 5. Search product ID
# 6. Remove product ID from cart
# 7. Display premium products (>= given value)
# 8. Union & Intersection with another cart
# 9. Display cart in sorted order
# 10. Exit
# Enter your choice:  1
# How many products to add?  5
# Enter product ID 1:  101
# Enter product ID 2:  205
# Enter product ID 3:  101
# Enter product ID 4:  450
# Enter product ID 5:  300
# Products added successfully!
#
# ====== SHOPPING CART SYSTEM (SET) ======
# 1. Add product IDs to cart
# 2. Display all products in cart
# 3. Total unique products count
# 4. Highest and Lowest product ID
# 5. Search product ID
# 6. Remove product ID from cart
# 7. Display premium products (>= given value)
# 8. Union & Intersection with another cart
# 9. Display cart in sorted order
# 10. Exit
# Enter your choice:  2
# ...

# %% [markdown]
# Debug the following code

# %%
s = {1, 2, 3}
lst = list(s)
print(lst[0])
# Out:
# 1

# %%
s = {10, 20, 30}
s.add(20)
print(s)
# Out:
# {10, 20, 30}
