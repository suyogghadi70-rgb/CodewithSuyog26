# %%
print("Suyog Ghadi")
print("24204C0024")
# Out:
# Suyog Ghadi
# 24204C0024

# %%
import math

num = int(input("Enter a number: "))
power = int(input("Enter power value: "))

print("Power:", math.pow(num, power))
print("Ceiling value:", math.ceil(num))
print("Square root:", math.sqrt(num))
print("Factorial:", math.factorial(num))
# Out:
# Power: 529.0
# ,Ceiling value: 23
# ,Square root: 4.795831523312719
# ,Factorial: 25852016738884976640000

# %%
str1 = input("Enter first string: ")
str2 = input("Enter second string: ")

print("Uppercase:", str1.upper())
print("Lowercase:", str1.lower())
print("Replace:", str1.replace("a", "@"))
print("Find position of 'a':", str1.find("a"))
print("Concatenation:", str1 + " " + str2)
# Out:
# Uppercase: HELLO
# ,Lowercase: hello
# ,Replace: Hello
# ,Find position of 'a': -1
# ,Concatenation: Hello World

# %%
def half_adder(a, b):
    sum_bit = a ^ b
    carry = a & b
    return sum_bit, carry

def full_adder(a, b, cin):
    sum_bit = a ^ b ^ cin
    carry = (a & b) | (b & cin) | (a & cin)
    return sum_bit, carry

a = int(input("Enter bit A (0 or 1): "))
b = int(input("Enter bit B (0 or 1): "))
cin = int(input("Enter Carry-in (0 or 1): "))

hs, hc = half_adder(a, b)
print("Half Adder -> Sum:", hs, "Carry:", hc)

fs, fc = full_adder(a, b, cin)
print("Full Adder -> Sum:", fs, "Carry:", fc)
# Out:
# Half Adder -> Sum: 1 Carry: 0
# ,Full Adder -> Sum: 0 Carry: 1

# %%
text = "Python is a powerful language"
result = text.find("language")

print("Index of 'language':", result)
# Out:
# Index of 'language': 21

# %%
import math
print(math.sqrt(25))
# Out:
# 5.0

# %%
def add(a, b):
    return a + b
